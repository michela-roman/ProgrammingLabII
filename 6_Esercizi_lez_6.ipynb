# %% [markdown]
# ### **1. Distribuzioni di probabilità**
# Genera 1000 valori casuali da una distribuzione gamma con parametro di forma pari a 1.
# Suggerimento: il parametro di forma viene passato come primo argomento quando si "congela" la distribuzione.
#
# Traccia l’istogramma del campione e sovrapponi la PDF della distribuzione.
#
# Stima il parametro di forma dal campione usando il metodo fit.
#
# Extra:
# Le distribuzioni hanno molti metodi utili. Esplorali usando il completamento automatico con il tasto TAB.
#
# Traccia la funzione di distribuzione cumulativa (CDF).
#
# Calcola la varianza.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma

# %%
# Generazione valori casuali
np.random.seed(42)
sample = np.random.gamma(1, 1, 1000)

# %%
# Istogramma e PDF
x = np.linspace(0, max(sample), 1000)

plt.hist(sample, bins = 30, density = True, label = 'Istogramma campione')

plt.plot(x, gamma.pdf(x, 1, 1), label = "PDF teorica")

plt.title("Distribuzione Gamma")
plt.xlabel("Valori")
plt.ylabel("Densità")
plt.legend()
plt.show()

# %%
# Stima del parametro di forma
shape_hat, loc_hat, scale_hat = gamma.fit(sample)

print("Parametro stimato (shape):", shape_hat)
print("loc:", loc_hat)
print("scale:", scale_hat)
# Out:
# Parametro stimato (shape): 0.9596112510552852
# loc: 0.004642784066342884
# scale: 1.0074484001678692

# %% [markdown]
# # Metodi delle distribuzioni
# gamma.pdf() funzione di densità di probabilità.
# gamma.cdf() funzione di distribuzione cumulativa.
# gamma.fit() stima i parametri (a, loc, scale) dal campione.
# gamma.freeze() permette di congelare una distribuzione con specifici parametri, in modo da non doverli passare ogni volta che vengono chiamate .pdf(), .cdf() eccetera.

# %%
# ESEMPIO:

np.random.seed(42)
sample = np.random.gamma(1, 1, 1000)

a_hat, loc_hat, scale_hat = gamma.fit(sample)

gamma_cong = gamma(a_hat, loc=loc_hat, scale=scale_hat)

media = gamma_cong.mean()
varianza = gamma_cong.var()
mediana = gamma_cong.median()

print("Media:", media)
print("Varianza:", varianza)
print("Mediana:", mediana)

media = gamma.mean(a = shape_hat, loc=loc_hat, scale=scale_hat)
print("Media: ", media)
# Out:
# Media: 0.9714016037250774
# Varianza: 0.9739596262133697
# Mediana: 0.6636249408750586
# Media:  0.9714016037250774

# %%
# CDF
cdf = gamma.cdf(x, a=shape_hat, loc=loc_hat, scale=scale_hat)

plt.plot(x, cdf, label='CDF stimata')
plt.title("CDF stimata della distribuzione Gamma")
plt.xlabel("Valori")
plt.ylabel("Probabilità cumulata")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Varianza
varianza = gamma.var(a = shape_hat, loc = loc_hat, scale = scale_hat)

# %% [markdown]
# ### **2. Fitta i dati**
# Prova a fittare i dati sottostante con le migliori curve, calcola il MAE e l'RMSE

# %%
import numpy as np

temp_max = np.array([17, 19, 21, 28, 33, 38, 37, 37, 31, 23, 19, 18])
temp_min = np.array([-62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58])

import matplotlib.pyplot as plt

months = np.arange(12)
plt.plot(months, temp_max, "ro")
plt.plot(months, temp_min, "bo")
plt.xlabel("Month")
plt.ylabel("Min and max temperature")
# Out:
# Text(0, 0.5, 'Min and max temperature')

# %%
mesi_interpolati = np.linspace(0, 11, 100) # dominio per disegnare la curva interpolata in modo liscio
coefficienti_massime = np.polyfit(months, temp_max, 4) # Coefficienti del polinomio di grado 4 che fitta i dati di temp_max
curva_massime = np.polyval(coefficienti_massime, mesi_interpolati) # Valuta il polinomio ottenuto sopra nei 100 punti di x_int
coefficienti_minime = np.polyfit(months, temp_min, 4)
curva_minime = np.polyval(coefficienti_minime, mesi_interpolati)

plt.title("Interpolazione numpy")
plt.plot(months, temp_max, "ro")
plt.plot(months, temp_min, "bo")
plt.xlabel("Month")
plt.ylabel("Min and max temperature")

# Curve interpolate
plt.plot(mesi_interpolati, curva_massime, color = 'orange')
plt.plot(mesi_interpolati, curva_minime, color = 'cyan')
plt.show()
stime_temp_max = np.polyval(coefficienti_massime, months)
stime_temp_min = np.polyval(coefficienti_minime, months)

# %%
# Calcolo MAE e RMSE
mae_massime = np.mean(np.abs(temp_max - stime_temp_max))
rmse_massime = np.sqrt(np.mean((temp_max - stime_temp_max) ** 2))

mae_minime = np.mean(np.abs(temp_min - stime_temp_min))
rmse_minime = np.sqrt(np.mean((temp_min - stime_temp_min) ** 2))

print("MAE temperature massime: ", mae_massime)
print("RMSE temperature massime: ", rmse_massime)
print("MAE temperature minime: ", mae_minime)
print("RMSE temperature minime: ", rmse_minime)
# Out:
# MAE temperature massime:  0.781177156177157
# RMSE temperature massime:  0.9301038867208568
# MAE temperature minime:  2.9569735819736356
# RMSE temperature minime:  3.487912490377843

# %% [markdown]
# # fit sinusoidale

# %%
from scipy.optimize import curve_fit

def funzione_seno(x, A, B, C, D):
    return A * np.sin(B * x + C) + D

parametri_max, _ = curve_fit(funzione_seno, months, temp_max, p0=[10, 2*np.pi/12, 0, 20])
parametri_min, _ = curve_fit(funzione_seno, months, temp_min, p0=[30, 2*np.pi/12, 0, -30])

x_fit = np.linspace(0, 11, 300)
fit_max = funzione_seno(x_fit, *parametri_max)
fit_min = funzione_seno(x_fit, *parametri_min)

plt.figure(figsize=(10, 6))
plt.plot(months, temp_max, "ro", label="Temp max osservate")
plt.plot(months, temp_min, "bo", label="Temp min osservate")
plt.plot(x_fit, fit_max, color="orange", label="Fit sinusoidale max")
plt.plot(x_fit, fit_min, color="cyan", label="Fit sinusoidale min")
plt.xlabel("Mese")
plt.ylabel("Temperatura")
plt.title("Fit sinusoidale delle temperature mensili")
plt.legend()
plt.grid(True)
plt.show()

# Stime nei punti originali
stime_max = funzione_seno(months, *parametri_max)
stime_min = funzione_seno(months, *parametri_min)

# %%
# Calcolo MAE e RMSE
mae_max = np.mean(np.abs(temp_max - stime_max))
rmse_max = np.sqrt(np.mean((temp_max - stime_max) ** 2))
mae_min = np.mean(np.abs(temp_min - stime_min))
rmse_min = np.sqrt(np.mean((temp_min - stime_min) ** 2))

print("MAE temp max:", mae_max)
print("RMSE temp max:", rmse_max)
print("MAE temp min:", mae_min)
print("RMSE temp min:", rmse_min)
# Out:
# MAE temp max: 0.7720553286471699
# RMSE temp max: 0.8479022664866716
# MAE temp min: 2.341009426083636
# RMSE temp min: 2.697276717046006

# %% [markdown]
# ### **3. Modello di regressione lineare dei seguenti dati**
#
#  Calcola un modello di regressione lineare delle colonne mpg e disp del famoso dataset mtcars.
#
# Dove:
#
# mpg = Miles Per Gallon → miglia per gallone, cioè una misura del consumo di carburante. Più alto è il valore, più efficiente è l’auto.
#
# disp = Displacement → cilindrata del motore, in pollici cubici (cubic inches). Rappresenta il volume totale dei cilindri del motore. Più è alto, maggiore è la potenza potenziale del motore (ma anche il consumo).

# %%
import pandas as pd

# Load dataset from URL
df = pd.read_csv('https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv')

# Display the dataframe
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
from scipy.stats import linregress

x = df['mpg']
y = df['disp']

slope, intercept, r_value, p_value, std_err = linregress(x, y)

print("Slope: ", slope)
print("Intercept", intercept)
print("R-quadro:", r_value**2)
print("p-value:", p_value)

y_pred = slope * x + intercept

# Grafico
plt.scatter(x, y, label='Dati reali')
plt.plot(x, y_pred, color='red', label='Regressione lineare')
plt.xlabel("Cilindrata (mpg)")
plt.ylabel("Consumo (disp)")
plt.title("Modello di regressione lineare: disp ~ mpg")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Slope:  -17.429121670356285
# Intercept 580.8838225585017
# R-quadro: 0.7183433404897296
# p-value: 9.380326537381565e-10
